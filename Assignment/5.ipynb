# %% [markdown]
# #Cnn_check_accuracy_with_muliple_layers_&_use_different_hyperparameters.

# %%
import tensorflow as tf

# %%
# class CustomCallbacks(tf.keras.callbacks.Callback):
#     def on_epoch_end(self, epoch, logs={}):
#       if(logs.get('acc')>0.998):
#         print("\n 99% acc reached")
#         self.model.stop_training = True


def preprocess_images(image_set):
  image_set = image_set.reshape(-1, 28, 28, 1)
  image_set = image_set / 255.0
  return image_set

# %%
mnist = tf.keras.datasets.mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()

training_images = preprocess_images(training_images)
test_images = preprocess_images(test_images)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(training_images,training_labels,batch_size=64,epochs=5)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 51s 55ms/step - loss: 0.1081 - accuracy: 0.9674
# Epoch 2/5
# 938/938 [==============================] - 48s 51ms/step - loss: 0.0505 - accuracy: 0.9847
# Epoch 3/5
# 938/938 [==============================] - 48s 51ms/step - loss: 0.0330 - accuracy: 0.9896
# Epoch 4/5
# 938/938 [==============================] - 50s 54ms/step - loss: 0.0238 - accuracy: 0.9922
# Epoch 5/5
# 938/938 [==============================] - 49s 52ms/step - loss: 0.0175 - accuracy: 0.9944

# %% [markdown]
# # **#Add multiple cnn layers & use differnt hyperparamters to train the model and upload the assignment**
